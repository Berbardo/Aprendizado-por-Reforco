# %%
import gym

env = gym.vector.make("CartPole-v1", num_envs=4, asynchronous=True)
env.seed(0)

# %%
from sac_discrete import SAC

actor = SAC(env.single_observation_space, env.single_action_space)

# %%
import time
import math
import numpy as np

def train(agent, env, total_timesteps, break_condition):
    total_rewards = [[] for _ in range(env.num_envs)]
    avg_total_rewards = []

    total_reward = np.zeros(env.num_envs)
    observations = env.reset()
    timestep = 0
    episode = 0

    t = 0
    
    start_time = time.time()

    while timestep < total_timesteps:
        actions = agent.act(observations)
        next_observations, rewards, dones, _ = env.step(actions)
        agent.remember(observations, actions, rewards, next_observations, dones)
        agent.train(64)
        
        timestep += len(observations)
        t += 1

        total_reward += rewards

        for i in range(env.num_envs):
            if dones[i]:
                total_rewards[i].append((t, timestep, total_reward[i]))
                episode += 1

        if any(G for G in total_rewards):
            episode_returns = sorted(
                list(np.concatenate([G for G in total_rewards if G])),
                key=lambda x: x[1]
            )

            avg_total_rewards.append(
                (t, timestep, np.mean([G[-1] for G in episode_returns[-20:]]))
            )

        total_reward *= 1 - dones
        observations = next_observations

        ratio = math.ceil(100 * timestep / total_timesteps)
        uptime = math.ceil(time.time() - start_time)

        avg_return = avg_total_rewards[-1][-1] if avg_total_rewards else np.nan

        print(f"[{ratio:3d}% / {uptime:3d}s] timestep = {timestep}/{total_timesteps}, episode = {episode:3d}, avg_return = {avg_return:10.4f}\r", end="")

        if avg_return > break_condition:
            return avg_total_rewards

    return avg_total_rewards

# %%
returns = train(actor, env, 100000, break_condition=450)
# Out:
# tensor([[ 0.0334,  0.0372],2/100000, episode =   9, avg_return =    23.4444
#         [ 0.0834, -0.0891],
#         [ 0.0621, -0.0636],
#         [ 0.0518, -0.0115]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 1., 1., 0.], device='cuda:0')
# tensor([[ 0.0334],
#         [-0.0891],
#         [-0.0636],
#         [ 0.0518]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[0.1808, 0.1505],256/100000, episode =   9, avg_return =    23.4444
#         [0.1849, 0.0190],
#         [0.2699, 0.0406],
#         [0.1536, 0.0313]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([1., 1., 1., 0.], device='cuda:0')
# tensor([[0.1505],
#         [0.0190],
#         [0.0406],
#         [0.1536]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[0.2575, 0.1642],260/100000, episode =   9, avg_return =    23.4444
#         [0.4219, 0.4864],
#         [0.3752, 0.1499],
#         [0.2494, 0.1277]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([1., 1., 1., 0.], device='cuda:0')
# tensor([[0.1642],
#         [0.4864],
#         [0.1499],
#         [0.2494]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[0.5520, 0.5454],264/100000, episode =   9, avg_return =    23.4444
#         [0.3535, 0.2255],
#         [0.3516, 0.2230],
#         [0.3558, 0.2323]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 0., 1., 0.], device='cuda:0')
# tensor([[0.5520],
#         [0.3535],
#         [0.2230],
#         [0.3558]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[0.6255, 0.5880],268/100000, episode =   9, avg_return =    23.4444
#         [0.5455, 0.4659],
#         [0.4585, 0.3212],
#         [0.7563, 0.7602]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([1., 0., 1., 1.], device='cuda:0')
# tensor([[0.5880],
#         [0.5455],
#         [0.3212],
#         [0.7602]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[0.9558, 0.9525],272/100000, episode =  10, avg_return =    22.9000
#         [1.0650, 1.0751],
#         [0.7723, 0.5004],
#         [0.5736, 0.4173]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([1., 1., 0., 1.], device='cuda:0')
# tensor([[0.9525],
#         [1.0751],
#         [0.7723],
#         [0.4173]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[0.6915, 0.5149],276/100000, episode =  10, avg_return =    22.9000
#         [0.6931, 0.5177],
#         [0.6888, 0.5165],
#         [0.6893, 0.5194]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([1., 1., 1., 0.], device='cuda:0')
# tensor([[0.5149],
#         [0.5177],
#         [0.5165],
#         [0.6893]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.5473, 1.0522],280/100000, episode =  10, avg_return =    22.9000
#         [0.8507, 0.6671],
#         [0.8224, 0.6050],
#         [0.8129, 0.6024]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 0., 0., 0.], device='cuda:0')
# tensor([[1.5473],
#         [0.8507],
#         [0.8224],
#         [0.8129]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[2.1413, 2.0821],284/100000, episode =  10, avg_return =    22.9000
#         [0.9724, 0.7351],
#         [0.9788, 0.7358],
#         [0.9854, 0.7906]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 0., 1., 0.], device='cuda:0')
# tensor([[2.1413],
#         [0.9724],
#         [0.7358],
#         [0.9854]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.4560, 1.2755],288/100000, episode =  10, avg_return =    22.9000
#         [1.0769, 0.8381],
#         [1.0864, 0.8415],
#         [1.4553, 1.2791]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 1., 0., 1.], device='cuda:0')
# tensor([[1.4560],
#         [0.8381],
#         [1.0864],
#         [1.2791]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.3441, 1.1325],292/100000, episode =  11, avg_return =    23.0000
#         [1.5824, 1.4304],
#         [2.2447, 2.1563],
#         [1.4347, 1.1150]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 0., 1., 0.], device='cuda:0')
# tensor([[1.3441],
#         [1.5824],
#         [2.1563],
#         [1.4347]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.3689, 1.1267],296/100000, episode =  11, avg_return =    23.0000
#         [1.5931, 1.4479],
#         [1.3236, 1.1441],
#         [1.2477, 1.0437]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 1., 1., 1.], device='cuda:0')
# tensor([[1.3689],
#         [1.4479],
#         [1.1441],
#         [1.0437]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[2.0249, 1.7146],300/100000, episode =  12, avg_return =    22.4167
#         [1.3173, 1.1548],
#         [1.3100, 1.1494],
#         [1.3104, 1.1535]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([1., 0., 1., 1.], device='cuda:0')
# tensor([[1.7146],
#         [1.3173],
#         [1.1494],
#         [1.1535]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.5202, 1.4206],304/100000, episode =  12, avg_return =    22.4167
#         [1.6844, 1.5118],
#         [2.2406, 1.9876],
#         [1.3863, 1.2683]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 1., 1., 1.], device='cuda:0')
# tensor([[1.5202],
#         [1.5118],
#         [1.9876],
#         [1.2683]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.4190, 1.3423],308/100000, episode =  12, avg_return =    22.4167
#         [1.4000, 1.3171],
#         [1.6467, 1.5356],
#         [1.3521, 1.2773]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 1., 1., 0.], device='cuda:0')
# tensor([[1.4190],
#         [1.3171],
#         [1.5356],
#         [1.3521]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.9200, 1.9313],312/100000, episode =  12, avg_return =    22.4167
#         [1.4077, 1.3628],
#         [1.3798, 1.3396],
#         [1.7558, 1.7465]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([1., 0., 0., 0.], device='cuda:0')
# tensor([[1.9313],
#         [1.4077],
#         [1.3798],
#         [1.7558]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.6272, 1.6295],316/100000, episode =  12, avg_return =    22.4167
#         [1.3275, 1.3179],
#         [1.3321, 1.3225],
#         [1.5021, 1.4943]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 0., 1., 0.], device='cuda:0')
# tensor([[1.6272],
#         [1.3275],
#         [1.3225],
#         [1.5021]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.7331, 1.7743],320/100000, episode =  12, avg_return =    22.4167
#         [1.3067, 1.3355],
#         [1.4884, 1.5540],
#         [1.4389, 1.4431]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([1., 1., 0., 0.], device='cuda:0')
# tensor([[1.7743],
#         [1.3355],
#         [1.4884],
#         [1.4389]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.2738, 1.3249],324/100000, episode =  12, avg_return =    22.4167
#         [1.7218, 1.7957],
#         [1.8600, 2.0185],
#         [1.2775, 1.3184]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 1., 1., 0.], device='cuda:0')
# tensor([[1.2738],
#         [1.7957],
#         [2.0185],
#         [1.2775]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.5795, 1.6359],328/100000, episode =  12, avg_return =    22.4167
#         [1.2329, 1.3062],
#         [1.2325, 1.3097],
#         [1.2417, 1.3047]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([0., 0., 1., 0.], device='cuda:0')
# tensor([[1.5795],
#         [1.2329],
#         [1.3097],
#         [1.2417]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.4719, 1.5197],332/100000, episode =  12, avg_return =    22.4167
#         [1.2146, 1.3309],
#         [1.2240, 1.3423],
#         [1.3670, 1.4096]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([1., 0., 0., 1.], device='cuda:0')
# tensor([[1.5197],
#         [1.2146],
#         [1.2240],
#         [1.4096]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([[1.4750, 1.5217],336/100000, episode =  12, avg_return =    22.4167
#         [1.6017, 1.6507],
#         [1.4395, 1.6566],
#         [1.1714, 1.2626]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor([1., 1., 0., 1.], device='cuda:0')
# tensor([[1.5217],
#         [1.6507],
#         [1.4395],
#         [1.2626]], device='cuda:0', grad_fn=<SelectBackward>)
# [  1% /   2s] timestep = 340/100000, episode =  12, avg_return =    22.4167
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-894751faa977> in <module>
# ----> 1 returns = train(actor, env, 100000, break_condition=450)
#
# <ipython-input-4-db0166724708> in train(agent, env, total_timesteps, break_condition)
#      20         next_observations, rewards, dones, _ = env.step(actions)
#      21         agent.remember(observations, actions, rewards, next_observations, dones)
# ---> 22         agent.train(64)
#      23
#      24         timestep += len(observations)
#
# D:\Git\Aprendizado-por-Reforço\SAC\sac_discrete.py in train(self, batch_size)
#     133         actions = torch.FloatTensor(actions).to(self.device)
#     134         rewards = torch.FloatTensor(rewards).unsqueeze(-1).to(self.device)
# --> 135         next_states = torch.FloatTensor(next_states).to(self.device)
#     136         dones = torch.FloatTensor(dones).unsqueeze(-1).to(self.device)
#     137
#
# KeyboardInterrupt:

# %%
import imageio
import numpy as np

def evaluate(agent, env, n_episodes=5, render=False, record=False):
    images = []
    for episode in range(n_episodes):
        obs = env.reset()        
        total_reward = 0.0
        episode_length = 0

        done = False
        while not done:
            action = agent.act(obs.reshape(1, *obs.shape))
            next_obs, reward, done, _ = env.step(action[0])
            obs = next_obs
            
            total_reward += reward
            episode_length += 1

            if render:
                env.render()
            if record:
                images.append(env.render(mode='rgb_array'))
        
        if render:
            env.close()

        print(f">> episode = {episode + 1} / {n_episodes}, total_reward = {total_reward:10.4f}, episode_length = {episode_length}")
        
    if record:
        imageio.mimsave('../img/CartPolePPO.gif', [np.array(img) for i, img in enumerate(images) if i%2 == 0], fps=29)

# %%
eval_env = gym.make("CartPole-v1")
evaluate(actor, eval_env, 1, True, False)

# %%
import matplotlib.pyplot as plt

rewards = np.transpose(returns)[2]
plt.plot(range(len(rewards)), rewards, label='Returns')
plt.legend()
plt.show()
